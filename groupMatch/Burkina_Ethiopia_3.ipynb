# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('../data/results.csv')
data.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland         4.0         2.0   Friendly   London
# 2  1874-03-07  Scotland   England         2.0         1.0   Friendly  Glasgow
# 3  1875-03-06   England  Scotland         2.0         2.0   Friendly   London
# 4  1876-03-04  Scotland   England         3.0         0.0   Friendly  Glasgow
#
#     country neutral
# 0  Scotland   False
# 1   England   False
# 2  Scotland   False
# 3   England   False
# 4  Scotland   False

# %%
burkina = data[(data['home_team'] == 'Burkina Faso') | (data['away_team'] == 'Burkina Faso')]

# %%
burkina.head()
# Out:
#             date     home_team     away_team  home_score  away_score  \
# 4689  1960-04-14         Gabon  Burkina Faso         4.0         5.0
# 4693  1960-04-15    Madagascar  Burkina Faso         6.0         1.0
# 5314  1963-02-01          Mali  Burkina Faso         1.0         0.0
# 6451  1967-01-29  Burkina Faso         Niger         3.0         2.0
# 6461  1967-02-12  Burkina Faso       Algeria         1.0         2.0
#
#                                 tournament          city      country neutral
# 4689                              Friendly  Antananarivo   Madagascar    True
# 4693                              Friendly  Antananarivo   Madagascar   False
# 5314                              Friendly        Bamako         Mali   False
# 6451                              Friendly   Ouagadougou  Upper Volta   False
# 6461  African Cup of Nations qualification   Ouagadougou  Upper Volta   False

# %%
brk_l20 = burkina[-20:]
brk_l20
# Out:
#              date     home_team     away_team  home_score  away_score  \
# 40866  2019-06-09      DR Congo  Burkina Faso         0.0         0.0
# 41132  2019-09-04         Libya  Burkina Faso         0.0         1.0
# 41186  2019-09-06       Morocco  Burkina Faso         1.0         1.0
# 41320  2019-09-22         Ghana  Burkina Faso         0.0         1.0
# 41348  2019-10-10         Gabon  Burkina Faso         1.0         0.0
# 41506  2019-10-20  Burkina Faso         Ghana         0.0         0.0
# 41517  2019-11-13  Burkina Faso        Uganda         0.0         0.0
# 41607  2019-11-17   South Sudan  Burkina Faso         1.0         2.0
# 41803  2020-10-09  Burkina Faso      DR Congo         3.0         0.0
# 41849  2020-10-12  Burkina Faso    Madagascar         2.0         1.0
# 42043  2021-03-24        Uganda  Burkina Faso         0.0         0.0
# 42142  2021-03-29  Burkina Faso   South Sudan         1.0         0.0
# ...

# %%
brk_win = 0
brk_lose = 0
brk_draw = 0
for i,j,k,l in zip(brk_l20['home_team'], brk_l20['away_team'], brk_l20['home_score'], brk_l20['away_score']):
    if ((i == 'Burkina Faso') and (k>l)) or ((j == 'Burkina Faso') and (k<l)):
        brk_win +=1
    elif ((i == 'Burkina Faso') and (k<l)) or ((j == 'Burkina Faso') and (k>l)):
        brk_lose +=1
    else:
        brk_draw += 1
    
print(brk_win, brk_lose, brk_draw)
# Out:
# 9 3 8

# %%
ethiopia = data[(data['home_team'] == 'Ethiopia') | (data['away_team'] == 'Ethiopia')]

# %%
ethiopia.tail()
# Out:
#              date     home_team     away_team  home_score  away_score  \
# 42692  2021-09-07      Ethiopia      Zimbabwe         1.0         0.0
# 42809  2021-10-09      Ethiopia  South Africa         1.0         3.0
# 42880  2021-10-12  South Africa      Ethiopia         1.0         0.0
# 42913  2021-11-11      Ethiopia         Ghana         1.0         1.0
# 42979  2021-11-14      Zimbabwe      Ethiopia         1.0         1.0
#
#                          tournament          city       country neutral
# 42692  FIFA World Cup qualification     Bahir Dar      Ethiopia   False
# 42809  FIFA World Cup qualification     Bahir Dar      Ethiopia   False
# 42880  FIFA World Cup qualification  Johannesburg  South Africa   False
# 42913  FIFA World Cup qualification  Johannesburg  South Africa    True
# 42979  FIFA World Cup qualification        Harare      Zimbabwe   False

# %%
eth_l20 = ethiopia[-20:]
eth_l20
# Out:
#              date     home_team     away_team  home_score  away_score  \
# 41113  2019-08-04      Ethiopia      Djibouti         4.0         3.0
# 41136  2019-09-04      Ethiopia       Lesotho         0.0         0.0
# 41236  2019-09-08       Lesotho      Ethiopia         1.0         1.0
# 41315  2019-09-22      Ethiopia        Rwanda         0.0         1.0
# 41425  2019-10-13      Ethiopia        Uganda         0.0         1.0
# 41494  2019-10-19        Rwanda      Ethiopia         1.0         1.0
# 41589  2019-11-16    Madagascar      Ethiopia         1.0         0.0
# 41655  2019-11-19      Ethiopia   Ivory Coast         2.0         1.0
# 41893  2020-11-06      Ethiopia         Sudan         2.0         2.0
# 42017  2021-03-17      Ethiopia        Malawi         4.0         0.0
# 42046  2021-03-24      Ethiopia    Madagascar         4.0         0.0
# 42179  2021-03-30   Ivory Coast      Ethiopia         3.0         1.0
# ...

# %%
eth_win = 0
eth_lose = 0
eth_draw = 0
for i,j,k,l in zip(eth_l20['home_team'], eth_l20['away_team'], eth_l20['home_score'], eth_l20['away_score']):
    if ((i == 'Ethiopia') and (k>l)) or ((j == 'Ethiopia') and (k<l)):
        eth_win +=1
    elif ((i == 'Ethiopia') and (k<l)) or ((j == 'Ethiopia') and (k>l)):
        eth_lose +=1
    else:
        eth_draw += 1
    
print(eth_win, eth_lose, eth_draw)
# Out:
# 6 7 7

# %%
labels = ['WIN', 'LOSE', 'DRAW']

brk = [brk_win, brk_lose, brk_draw]
eth = [eth_win, eth_lose, eth_draw]

width = 0.25

x = np.arange(0, 3)

fig, ax = plt.subplots(figsize=(10,10))

y = list(range(0, 16, 2))

rects1 = ax.bar(x - width/2, brk, width, label='Burkina Faso', color='g')
rects2 = ax.bar(x + width/2, eth, width, label='Ethiopia', color='y')

ax.set_ylabel('Number of Outcomes',fontsize=30, color='r')
ax.set_xlabel("Outcomes", fontsize=30, color='r')
ax.set_title("The last 20 matches of Burkina and Ethiopia", fontsize=25, color='b')
ax.set_xticklabels(labels, fontsize=15, color='b')
ax.set_yticklabels(y, rotation=0, fontsize=25, color='b')

ax.set_xticks(x)
plt.legend(fontsize=15)
plt.grid(True)
plt.savefig("burkina_ethiopia.png")
# Out:
# C:\Users\sanka\AppData\Local\Temp/ipykernel_3676/1079423023.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels, fontsize=15, color='b')
# C:\Users\sanka\AppData\Local\Temp/ipykernel_3676/1079423023.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(y, rotation=0, fontsize=25, color='b')
