# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('../data/results.csv')
data.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland         4.0         2.0   Friendly   London
# 2  1874-03-07  Scotland   England         2.0         1.0   Friendly  Glasgow
# 3  1875-03-06   England  Scotland         2.0         2.0   Friendly   London
# 4  1876-03-04  Scotland   England         3.0         0.0   Friendly  Glasgow
#
#     country neutral
# 0  Scotland   False
# 1   England   False
# 2  Scotland   False
# 3   England   False
# 4  Scotland   False

# %%
malawi = data[(data['home_team'] == 'Malawi') | (data['away_team'] == 'Malawi')]

# %%
malawi.head()
# Out:
#             date home_team away_team  home_score  away_score tournament  \
# 4227  1957-08-28    Malawi    Zambia         0.0         5.0   Friendly
# 5239  1962-10-15    Malawi     Ghana         0.0        12.0   Friendly
# 5289  1962-12-08  Tanzania    Malawi         6.0         2.0   Friendly
# 5444  1963-07-06    Zambia    Malawi         5.0         1.0   Friendly
# 5660  1964-07-04    Malawi    Zambia         0.0         5.0   Friendly
#
#                city            country neutral
# 4227       Blantyre          Nyasaland   False
# 5239       Blantyre          Nyasaland   False
# 5289  Dar es Salaam         Tanganyika   False
# 5444          Kitwe  Northern Rhodesia   False
# 5660       Blantyre          Nyasaland   False

# %%
malawi_l20 = malawi[-20:]
malawi_l20
# Out:
#              date    home_team    away_team  home_score  away_score  \
# 41299  2019-09-10       Malawi     Botswana         1.0         0.0
# 41427  2019-10-13      Lesotho       Malawi         1.0         1.0
# 41516  2019-11-13       Malawi  South Sudan         1.0         0.0
# 41608  2019-11-17       Uganda       Malawi         2.0         0.0
# 41794  2020-10-07       Zambia       Malawi         1.0         0.0
# 41846  2020-10-11       Malawi     Zimbabwe         0.0         0.0
# 42017  2021-03-17     Ethiopia       Malawi         4.0         0.0
# 42042  2021-03-24  South Sudan       Malawi         0.0         1.0
# 42143  2021-03-29       Malawi       Uganda         1.0         0.0
# 42389  2021-06-13     Tanzania       Malawi         2.0         0.0
# 42509  2021-07-09       Malawi     Zimbabwe         2.0         2.0
# 42517  2021-07-11   Mozambique       Malawi         2.0         0.0
# 42526  2021-07-13       Malawi      Namibia         1.0         1.0
# ...

# %%
malawi_win = 0
malawi_lose = 0
malawi_draw = 0
for i,j,k,l in zip(malawi_l20['home_team'], malawi_l20['away_team'], malawi_l20['home_score'], malawi_l20['away_score']):
    if ((i == 'Malawi') and (k>l)) or ((j == 'Malawi') and (k<l)):
        malawi_win +=1
    elif ((i == 'Malawi') and (k<l)) or ((j == 'Malawi') and (k>l)):
        malawi_lose +=1
    else:
        malawi_draw += 1
    
print(malawi_win, malawi_lose, malawi_draw)
# Out:
# 5 11 4

# %%
senegal = data[(data['home_team'] == 'Senegal') | (data['away_team'] == 'Senegal')]

# %%
senegal.tail()
# Out:
#              date home_team away_team  home_score  away_score  \
# 42693  2021-09-07     Congo   Senegal         1.0         3.0
# 42812  2021-10-09   Senegal   Namibia         4.0         1.0
# 42881  2021-10-12   Namibia   Senegal         1.0         3.0
# 42916  2021-11-11      Togo   Senegal         1.0         1.0
# 42981  2021-11-14   Senegal     Congo         2.0         0.0
#
#                          tournament          city       country neutral
# 42693  FIFA World Cup qualification   Brazzaville         Congo   False
# 42812  FIFA World Cup qualification         Thiès       Senegal   False
# 42881  FIFA World Cup qualification  Johannesburg  South Africa    True
# 42916  FIFA World Cup qualification          Lomé          Togo   False
# 42981  FIFA World Cup qualification         Thiès       Senegal   False

# %%
senegal_l20 = senegal[-20:]
senegal_l20
# Out:
#              date     home_team   away_team  home_score  away_score  \
# 41504  2019-10-20        Guinea     Senegal         1.0         0.0
# 41523  2019-11-13       Senegal       Congo         2.0         0.0
# 41613  2019-11-17      Eswatini     Senegal         1.0         4.0
# 41809  2020-10-09       Morocco     Senegal         3.0         1.0
# 42086  2021-03-26         Congo     Senegal         0.0         0.0
# 42178  2021-03-30       Senegal    Eswatini         1.0         1.0
# 42282  2021-06-05       Senegal      Zambia         3.0         1.0
# 42335  2021-06-08       Senegal  Cape Verde         2.0         0.0
# 42505  2021-07-07       Senegal     Namibia         1.0         2.0
# 42510  2021-07-09       Senegal  Mozambique         1.0         0.0
# 42525  2021-07-13       Senegal    Zimbabwe         2.0         1.0
# 42532  2021-07-14       Senegal      Malawi         2.0         1.0
# 42537  2021-07-16       Senegal    Eswatini         2.0         2.0
# ...

# %%
senegal_win = 0
senegal_lose = 0
senegal_draw = 0
for i,j,k,l in zip(senegal_l20['home_team'], senegal_l20['away_team'], senegal_l20['home_score'], senegal_l20['away_score']):
    if ((i == 'Senegal') and (k>l)) or ((j == 'Senegal') and (k<l)):
        senegal_win +=1
    elif ((i == 'Senegal') and (k<l)) or ((j == 'Senegal') and (k>l)):
        senegal_lose +=1
    else:
        senegal_draw += 1
    
print(senegal_win, senegal_lose, senegal_draw)
# Out:
# 12 3 5

# %%
labels = ['WIN', 'LOSE', 'DRAW']

sen = [senegal_win, senegal_lose, senegal_draw]
malwi = [malawi_win, malawi_lose, malawi_draw]

width = 0.25

x = np.arange(0, 3)

fig, ax = plt.subplots(figsize=(10,10))

y = list(range(0, 16, 2))

rects1 = ax.bar(x - width/2, sen, width, label='Senegal', color='g')
rects2 = ax.bar(x + width/2, malwi, width, label='Malawi', color='k')

ax.set_ylabel('Number of Outcomes',fontsize=30, color='r')
ax.set_xlabel("Outcomes", fontsize=30, color='r')
ax.set_title("The last 20 matches of Senegal and Malawi", fontsize=25, color='b')
ax.set_xticklabels(labels, fontsize=15, color='b')
ax.set_yticklabels(y, rotation=0, fontsize=25, color='b')

ax.set_xticks(x)
plt.legend(fontsize=15)
plt.grid(True)
#plt.show()
#plt.savefig("senegal_malawi.png")
# Out:
# C:\Users\sanka\AppData\Local\Temp/ipykernel_11768/1135249752.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels, fontsize=15, color='b')
# C:\Users\sanka\AppData\Local\Temp/ipykernel_11768/1135249752.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(y, rotation=0, fontsize=25, color='b')
