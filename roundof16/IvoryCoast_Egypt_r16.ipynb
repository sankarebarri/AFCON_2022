# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data/results.csv')
data.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland         4.0         2.0   Friendly   London
# 2  1874-03-07  Scotland   England         2.0         1.0   Friendly  Glasgow
# 3  1875-03-06   England  Scotland         2.0         2.0   Friendly   London
# 4  1876-03-04  Scotland   England         3.0         0.0   Friendly  Glasgow
#
#     country neutral
# 0  Scotland   False
# 1   England   False
# 2  Scotland   False
# 3   England   False
# 4  Scotland   False

# %%
ivory_egypt = data[((data['home_team'] == 'Ivory Coast') & (data['away_team'] == 'Egypt')) | (data['home_team'] == 'Egypt') & (data['away_team'] == 'Ivory Coast')]

# %%
ivory_egypt
# Out:
#              date    home_team    away_team  home_score  away_score  \
# 7429   1970-02-16        Egypt  Ivory Coast         3.0         1.0
# 8998   1974-03-06        Egypt  Ivory Coast         2.0         0.0
# 11281  1980-03-08        Egypt  Ivory Coast         2.0         1.0
# 13095  1984-03-07  Ivory Coast        Egypt         1.0         2.0
# 13575  1985-01-31  Ivory Coast        Egypt         0.0         1.0
# 14089  1985-11-19        Egypt  Ivory Coast         0.0         1.0
# 14212  1986-03-10        Egypt  Ivory Coast         2.0         0.0
# 16057  1990-03-03  Ivory Coast        Egypt         3.0         1.0
# 17172  1992-07-26  Ivory Coast        Egypt         2.0         0.0
# 17175  1992-07-28  Ivory Coast        Egypt         2.0         2.0
# 21237  1998-02-21  Ivory Coast        Egypt         0.0         0.0
# 21664  1998-09-16        Egypt  Ivory Coast         0.0         0.0
# 22574  2000-01-09  Ivory Coast        Egypt         2.0         0.0
# ...

# %%
len(ivory_egypt)
# Out:
# 22

# %%
neutral = ivory_egypt[ivory_egypt['neutral']]
neutral
# Out:
#              date    home_team    away_team  home_score  away_score  \
# 7429   1970-02-16        Egypt  Ivory Coast         3.0         1.0
# 11281  1980-03-08        Egypt  Ivory Coast         2.0         1.0
# 14089  1985-11-19        Egypt  Ivory Coast         0.0         1.0
# 16057  1990-03-03  Ivory Coast        Egypt         3.0         1.0
# 21237  1998-02-21  Ivory Coast        Egypt         0.0         0.0
# 29573  2007-08-22  Ivory Coast        Egypt         0.0         0.0
# 30112  2008-02-07  Ivory Coast        Egypt         1.0         4.0
# 34966  2013-01-14  Ivory Coast        Egypt         4.0         2.0
#
#                    tournament         city               country neutral
# 7429   African Cup of Nations     Khartoum                 Sudan    True
# 11281  African Cup of Nations        Lagos               Nigeria    True
# 14089                Friendly     Kinshasa                 Zaïre    True
# ...

# %%
friendly = ivory_egypt[ivory_egypt['tournament'] == 'Friendly']
friendly
# Out:
#              date    home_team    away_team  home_score  away_score  \
# 13575  1985-01-31  Ivory Coast        Egypt         0.0         1.0
# 14089  1985-11-19        Egypt  Ivory Coast         0.0         1.0
# 17172  1992-07-26  Ivory Coast        Egypt         2.0         0.0
# 17175  1992-07-28  Ivory Coast        Egypt         2.0         2.0
# 21664  1998-09-16        Egypt  Ivory Coast         0.0         0.0
# 22574  2000-01-09  Ivory Coast        Egypt         2.0         0.0
# 29573  2007-08-22  Ivory Coast        Egypt         0.0         0.0
# 34966  2013-01-14  Ivory Coast        Egypt         4.0         2.0
#
#       tournament       city               country neutral
# 13575   Friendly    Abidjan           Ivory Coast   False
# 14089   Friendly   Kinshasa                 Zaïre    True
# 17172   Friendly    Abidjan           Ivory Coast   False
# 17175   Friendly    Abidjan           Ivory Coast   False
# 21664   Friendly      Cairo                 Egypt   False
# ...

# %%
not_friendly = ivory_egypt[ivory_egypt['tournament'] != 'Friendly']
not_friendly
# Out:
#              date    home_team    away_team  home_score  away_score  \
# 7429   1970-02-16        Egypt  Ivory Coast         3.0         1.0
# 8998   1974-03-06        Egypt  Ivory Coast         2.0         0.0
# 11281  1980-03-08        Egypt  Ivory Coast         2.0         1.0
# 13095  1984-03-07  Ivory Coast        Egypt         1.0         2.0
# 14212  1986-03-10        Egypt  Ivory Coast         2.0         0.0
# 16057  1990-03-03  Ivory Coast        Egypt         3.0         1.0
# 21237  1998-02-21  Ivory Coast        Egypt         0.0         0.0
# 23339  2000-09-02        Egypt  Ivory Coast         1.0         0.0
# 24196  2001-06-17  Ivory Coast        Egypt         2.0         2.0
# 26805  2004-06-20        Egypt  Ivory Coast         1.0         2.0
# 27742  2005-06-19  Ivory Coast        Egypt         2.0         0.0
# 28217  2006-01-28        Egypt  Ivory Coast         3.0         1.0
# 28240  2006-02-10        Egypt  Ivory Coast         0.0         0.0
# ...

# %%
afcon = ivory_egypt[ivory_egypt['tournament'] == 'African Cup of Nations']
afcon
# Out:
#              date    home_team    away_team  home_score  away_score  \
# 7429   1970-02-16        Egypt  Ivory Coast         3.0         1.0
# 8998   1974-03-06        Egypt  Ivory Coast         2.0         0.0
# 11281  1980-03-08        Egypt  Ivory Coast         2.0         1.0
# 13095  1984-03-07  Ivory Coast        Egypt         1.0         2.0
# 14212  1986-03-10        Egypt  Ivory Coast         2.0         0.0
# 16057  1990-03-03  Ivory Coast        Egypt         3.0         1.0
# 21237  1998-02-21  Ivory Coast        Egypt         0.0         0.0
# 28217  2006-01-28        Egypt  Ivory Coast         3.0         1.0
# 28240  2006-02-10        Egypt  Ivory Coast         0.0         0.0
# 30112  2008-02-07  Ivory Coast        Egypt         1.0         4.0
#
#                    tournament         city       country neutral
# 7429   African Cup of Nations     Khartoum         Sudan    True
# 8998   African Cup of Nations        Cairo         Egypt   False
# ...

# %%
def get_results(competition, country_A, country_B):
    win_A = 0 # country A win
    draw = 0 # draw of country_A and country_B are equal
    #lost_A = 0 # country A lost
    for i, j, k, l in zip(competition['home_team'], competition['away_team'], competition['home_score'], competition['away_score']):
        if ((i == country_A and k > l) or (j == country_A and k < l)):
            win_A += 1
        elif ((i == country_A and k == l) or (j == country_A and k == l)):
            draw += 1
    return [win_A, draw, len(competition)-(win_A + draw)]

# %%
get_results(ivory_egypt, 'Ivory Coast', 'Egypt')
# Out:
# [7, 6, 9]

# %%
labels1 = ['IVORY COAST WON(1)', 'DRAW(2)', 'EGYPT WON(7)']
sizes1 = get_results(afcon, 'Ivory Coast', 'Egypt')

labels2 = ['IVORY COAST WON(4)', 'DRAW(3)', 'EGYPT WON(1)']
sizes2 = get_results(friendly, 'Ivory Coast', 'Egypt')

labels3 = ['IVORY COAST WON(3)', 'DRAW(3)', 'EGYPT WON(8)']
sizes3 = get_results(not_friendly, 'Ivory Coast', 'Egypt')

labels4 = ['IVORY COAST WON(3)', 'DRAW(2)', 'EGYPT WON(3)']
sizes4 = get_results(neutral, 'Ivory Coast', 'Egypt')

fig, ([ax1, ax2], [ax3, ax4]) = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

ax1.pie(sizes1, labels=labels1, autopct='%.0f%%')
ax2.pie(sizes2, labels=labels2, autopct='%.0f%%')
ax3.pie(sizes3, labels=labels3, autopct='%.0f%%')
ax4.pie(sizes4, labels=labels4, autopct='%.0f%%')

ax1.set_title('AFCON MATCHES(7)', color='b', fontsize='15')
ax2.set_title('FRIENDLY MATCHES(8)', color='b', fontsize='15')
ax3.set_title('NON-FRIENDLY MATCHES(14)', color='b', fontsize='15')
ax4.set_title('NEUTRAL GROUNDS(8)', color='b', fontsize='15')

#plt.show()
plt.savefig("images/ivoryCoast_egypt1.png")

# %%
labels = ['IVORY COAST WON(7)', 'DRAW(6)', 'EGYPT WON(9)']
sizes = get_results(ivory_egypt, 'Ivory Coast', 'Egypt')

fig, ax1 = plt.subplots(figsize=(10, 10))

ax1.pie(sizes, labels=labels, autopct='%.0f%%')
ax1.set_title('IVORY COAST vs EGYPT ALL MATCHES(22)', color='b', fontsize='25')


#plt.show()
plt.savefig("images/ivoryCoast_egypt2.png")
